# %% [markdown]
# # feyntensor examples

# %%
load('graphs_intro.sage') # blame/ask author: carlos
load('feyntensor.sage')  # blame/ask author: carlos
FeynmanGr?
# Out:
# Signature:      FeynmanGr(bubbles)
# Docstring:         Connected Feynman diagrams
# Init docstring: Initialize self.  See help(type(self)) for accurate signature.
# File:           Dynamically generated function. No source code available.
# Type:           function

# %% [markdown]
# ## Visualisation

# %%
invariant = V1
marking_coloring([invariant])[0][0].plot( # the graph
       edge_colors=marking_coloring([invariant])[1][0],figsize=(1, 1) ) # << colors to plot
# Out:
# Graphics object consisting of 11 graphics primitives

# %%
invariant = Cube
marking_coloring([invariant])[0][0].plot( # the graph
       edge_colors=marking_coloring([invariant])[1][0],figsize=(1.3, 1.3) ) # << colors to plot
# Out:
# Graphics object consisting of 21 graphics primitives

# %%
invariant = Y1
marking_coloring([invariant])[0][0].plot( # the graph
       edge_colors=marking_coloring([invariant])[1][0],figsize=(1.3, 1.3) ) # << colors to plot
# Out:
# Graphics object consisting of 21 graphics primitives

# %% [markdown]
# ## Integrals

# %%
Integrate([Mel,V1,V1,V1,V1])
# Out:
# 35712/N + 62976/N^2 + 35712/N^3 + 32256/N^4 + 64128/N^5 + 26880/N^6 + 8064/N^8 + 5376

# %%
Integrate([Mel,V1,V1,V1,V2])
# Out:
# 27648/N + 52608/N^2 + 54144/N^3 + 50688/N^4 + 45696/N^5 + 26880/N^6 + 8064/N^7 + 5376

# %%
Integrate([Mel,V1,V1,V2,V2])
# Out:
# 25088/N + 50432/N^2 + 56960/N^3 + 53760/N^4 + 53504/N^5 + 21504/N^6 + 4480/N^8 + 5376

# %%
Integrate([Mel,V1,V1,V2,V3])
# Out:
# 23296/N + 46336/N^2 + 64512/N^3 + 63232/N^4 + 38016/N^5 + 20608/N^6 + 9728/N^7 + 5376

# %% [markdown]
# ## Feynman integrals visualisation

# %%
show_random_FeynGraphs([Y1],6)
# Out:
# done, entries are: 0: Feynman grs, 1: colorations, 2: sum of amplitudes, 3: degrees, 4: melons, 5: grb loops
# amplitudes: 8/N + 9/N^2 + 4/N^3 + 1/N^4 + 2
# Amplitude of this graph is: N^(-3)
# Bicoloured loops of this graph are: [2, 2, 1]
# Graphics object consisting of 17 graphics primitives
# Amplitude of this graph is: N^(-3)
# Bicoloured loops of this graph are: [2, 2, 1]
# Graphics object consisting of 17 graphics primitives
# Amplitude of this graph is: N^(-3)
# Bicoloured loops of this graph are: [2, 2, 1]
# Graphics object consisting of 17 graphics primitives
# Amplitude of this graph is: 1
# Bicoloured loops of this graph are: [3, 3, 2]
# Graphics object consisting of 17 graphics primitives
# Amplitude of this graph is: 1/N
# Bicoloured loops of this graph are: [2, 2, 3]
# Graphics object consisting of 17 graphics primitives
# Amplitude of this graph is: N^(-2)
# Bicoloured loops of this graph are: [1, 1, 4]
# Graphics object consisting of 17 graphics primitives

# %%
show_random_FeynGraphs([V1,V2],3)
# Out:
# done, entries are: 0: Feynman grs, 1: colorations, 2: sum of amplitudes, 3: degrees, 4: melons, 5: grb loops
# amplitudes: 8/N + 6/N^2 + 2/N^3 + 4
# Amplitude of this graph is: N^(-2)
# Bicoloured loops of this graph are: [2, 2, 1]
# Graphics object consisting of 17 graphics primitives
# Amplitude of this graph is: 1/N
# Bicoloured loops of this graph are: [1, 3, 2]
# Graphics object consisting of 17 graphics primitives
# Amplitude of this graph is: N^(-2)
# Bicoloured loops of this graph are: [2, 2, 1]
# Graphics object consisting of 17 graphics primitives
